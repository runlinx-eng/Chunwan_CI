# %% [markdown]
# # Pre-Holiday A-Share Screener Demo
# This notebook runs the CLI and loads the JSON output for quick inspection.

# %%
# !python -m src.run --date 2026-01-20 --top 5

# %%
import json
from pathlib import Path

report_path = Path('outputs') / 'report_2026-01-20_top5.json'
report = json.loads(report_path.read_text(encoding='utf-8'))
report['results'][:3]
